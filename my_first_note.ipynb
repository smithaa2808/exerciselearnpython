# %%
chocolate = "Cadburys"
# This  is how I create we variables

# %%
print(chocolate)

# %%
print(chocolate)

# %%
print(chocolate)

# %%
chocolate

# %%
print('I am a programmer')

# %% [raw]
# print("""I am a programmer,
# learning to code python""")

# %%
print("The escape character is\n. Can you see it now")
# \n is the special character
# Out:
# The escape character is
# . Can you see it now

# %%
print("The escape character is\\n. Can you see it now")
# Out:
# The escape character is\n. Can you see it now
